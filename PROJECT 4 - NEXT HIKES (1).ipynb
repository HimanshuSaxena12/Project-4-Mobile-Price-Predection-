# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Mobile Data.csv')
df
# Out:
#      Unnamed: 0                  Model          Colour  Memory  RAM  Battery_  \
# 0             0        Infinix SMART 7     Night Black      64    4      6000
# 1             1        Infinix SMART 7      Azure Blue      64    4      6000
# 2             2           MOTOROLA G32    Mineral Gray     128    8      5000
# 3             3               POCO C50      Royal Blue      32    2      5000
# 4             4        Infinix HOT 30i        Marigold     128    8      5000
# ..          ...                    ...             ...     ...  ...       ...
# 536         637  SAMSUNG Galaxy S23 5G           Cream     256    8      3900
# 537         638               LAVA Z21            Cyan      32    2      3100
# 538         639         Tecno Spark 8T  Turquoise Cyan      64    4      5000
# 539         641  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000
# 540         642               OPPO A77        Sky Blue     128    4      5000
#
# ...

# %%
df.shape
# Out:
# (541, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     541 non-null    int64
#  1   Model          541 non-null    object
#  2   Colour         541 non-null    object
#  3   Memory         541 non-null    int64
#  4   RAM            541 non-null    int64
#  5   Battery_       541 non-null    int64
#  6   Rear Camera    541 non-null    object
#  7   Front Camera   541 non-null    object
#  8   AI Lens        541 non-null    int64
#  9   Mobile Height  541 non-null    float64
#  10  Processor_     541 non-null    object
#  11  Prize          541 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 50.8+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0      Memory         RAM     Battery_     AI Lens  \
# count  541.000000  541.000000  541.000000   541.000000  541.000000
# mean   289.711645  110.550832    5.397412  4871.587800    0.062847
# std    182.359185   60.600694    1.984923   780.148862    0.242911
# min      0.000000   16.000000    2.000000   800.000000    0.000000
# 25%    135.000000   64.000000    4.000000  5000.000000    0.000000
# 50%    273.000000  128.000000    6.000000  5000.000000    0.000000
# 75%    434.000000  128.000000    8.000000  5000.000000    0.000000
# max    642.000000  256.000000    8.000000  7000.000000    1.000000
#
#        Mobile Height
# count     541.000000
# mean       16.431201
# std         2.523553
# min         4.500000
# 25%        16.510000
# 50%        16.710000
# 75%        16.940000
# max        41.940000

# %%
df.isnull().sum()    # NO Null Values in Dataset
# Out:
# Unnamed: 0       0
# Model            0
# Colour           0
# Memory           0
# RAM              0
# Battery_         0
# Rear Camera      0
# Front Camera     0
# AI Lens          0
# Mobile Height    0
# Processor_       0
# Prize            0
# dtype: int64

# %% [markdown]
# ***Cleaning data***

# %%
cleaned_data = []
for item in df:
    try:
        cleaned_data.append(float(item))
    except ValueError:
        continue

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# # ***Statistical Analysis***

# %% [markdown]
# ***Correlation analysis***

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25464\868109210.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
#                Unnamed: 0    Memory       RAM  Battery_   AI Lens  \
# Unnamed: 0       1.000000  0.120579  0.084103 -0.057136 -0.160373
# Memory           0.120579  1.000000  0.625284 -0.053210 -0.094442
# RAM              0.084103  0.625284  1.000000 -0.104923 -0.082622
# Battery_        -0.057136 -0.053210 -0.104923  1.000000  0.150156
# AI Lens         -0.160373 -0.094442 -0.082622  0.150156  1.000000
# Mobile Height    0.015372  0.063163  0.092951  0.695641  0.052018
#
#                Mobile Height
# Unnamed: 0          0.015372
# Memory              0.063163
# RAM                 0.092951
# Battery_            0.695641
# AI Lens             0.052018
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ***HEAT MAP***

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(),
			cmap = 'BrBG',
			fmt = '.2f',
			linewidths = 2,
			annot = True).set_title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# **BAR PLOT**

# %%
# Analyze unique values in battery colum in Dataset
plt.figure(figsize=(10, 6))
sns.countplot(x='Battery_', data=df, palette='viridis')
plt.title('Unique Values Analysis')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25464\2123529813.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Battery_', data=df, palette='viridis')

# %%
# Analyze unique values in Processor colum in Dataset
plt.figure(figsize=(10, 6))
sns.countplot(x='Processor_', data=df, palette='viridis')
plt.title('Unique Values Analysis')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25464\3841158943.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Processor_', data=df, palette='viridis')

# %%
#Finding Outliers in Battery 
plt.figure(figsize=(10,5))
plt.subplot(3,1,1)
sns.boxplot(x=df.Battery_ ).set_title('outliers in Battery')

plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(3,1,1)
sns.boxplot(x=df.Processor_).set_title('outliers in Processor')

plt.show()

# %% [markdown]
# ***VALUE COUNTS***

# %%
df['Model'].value_counts()
# Out:
# vivo Y16                 9
# realme C55               9
# SAMSUNG Galaxy A14 5G    9
# REDMI Note 12 Pro 5G     9
# vivo T1 44W              8
#                         ..
# vivo Y1s                 1
# OnePlus Nord             1
# Micromax 3               1
# vivo Y33s                1
# OPPO A77                 1
# Name: Model, Length: 187, dtype: int64

# %%
df['Colour'].value_counts()
# Out:
# Yellow            12
# Royal Blue         8
# Power Black        8
# Black              8
# Midnight Black     7
#                   ..
# Polar Blue         1
# Cosmic grey        1
# Sea                1
# Infinity Black     1
# Sky Blue           1
# Name: Colour, Length: 275, dtype: int64

# %%
df['Battery_'].value_counts()
# Out:
# 5000    389
# 6000     42
# 4500     26
# 5080      6
# 4980      6
# 4300      5
# 4200      5
# 4400      5
# 800       5
# 1000      4
# 4700      4
# 1020      3
# 4830      3
# 4600      3
# 4270      3
# 4323      3
# 4050      2
# 5020      2
# 3000      2
# 5200      2
# 4800      2
# 4610      2
# 4020      2
# 4410      2
# 4000      1
# 4030      1
# 4115      1
# 3300      1
# 3110      1
# 1500      1
# 1200      1
# 2550      1
# 1900      1
# 7000      1
# 2815      1
# 3900      1
# 3100      1
# Name: Battery_, dtype: int64

# %%
df['Processor_'].value_counts()
# Out:
# Qualcomm Snapdragon 680        33
# Unisoc T612                    21
# Mediatek Helio A22             19
# Mediatek Dimensity 1080        18
# Qualcomm Snapdragon 695 5G     17
#                                ..
# Qualcomm Snapdragon 439         1
# Snapdragon 680                  1
# snapdragon 888                  1
# Qualcomm Snapdragon 855         1
# Qualcomm Snapdragon 8 Gen 2     1
# Name: Processor_, Length: 123, dtype: int64

# %% [markdown]
# ***OneHotEncoder***

# %%
from sklearn.preprocessing import OneHotEncoder

s = (df.dtypes == 'object')
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
print('No. of. categorical features: ', 
	len(object_cols))
# Out:
# Categorical variables:
# ['Model', 'Colour', 'Rear Camera', 'Front Camera', 'Processor_', 'Prize']
# No. of. categorical features:  6

# %% [markdown]
# ***Convert All Categorical data to Numerical data using LabelEncoder***

# %%
from sklearn.preprocessing import LabelEncoder


label_encoder = LabelEncoder()

# Apply label encoding to each column with string data
for column in df.select_dtypes(include=['object']).columns:
    df[column] = label_encoder.fit_transform(df[column])

# %%
df
# Out:
#      Unnamed: 0  Model  Colour  Memory  RAM  Battery_  Rear Camera  \
# 0             0     23     159      64    4      6000            3
# 1             1     23      20      64    4      6000            3
# 2             2     37     149     128    8      5000           10
# 3             3     69     201      32    2      5000           13
# 4             4     12     130     128    8      5000           10
# ..          ...    ...     ...     ...  ...       ...          ...
# 536         637    118      49     256    8      3900           10
# 537         638     32      52      32    2      3100           11
# 538         639    123     259      64    4      5000           10
# 539         641    110      17     128    8      5000           10
# 540         642     59     215     128    4      5000           10
#
#      Front Camera  AI Lens  Mobile Height  Processor_  Prize
# 0              10        1          16.76         113    125
# ...

# %% [markdown]
# ***X & Y ARRAY***

# %%
X = df.drop('Prize',axis=1)

# %%
y = df['Prize']

# %% [markdown]
# # Splitting Dataset into Training and Testing

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %% [markdown]
# ***Creating & Training Linear Regression Model***

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lm.score(X_test,y_test)
# Out:
# 0.18666754126645513

# %% [markdown]
# ***Creating & Training Logistic Regression Mode***

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logmodel.score(X_test,y_test)
# Out:
# 0.09497206703910614

# %% [markdown]
# ***Creating & Training Random Tree Model***

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=200)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rfc.score(X_test,y_test)
# Out:
# 0.4972067039106145

# %% [markdown]
# # Analyze model's performance

# %% [markdown]
# ***Mean Absolute Error***

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 10.597765363128492

# %% [markdown]
# ***Mean Squared Error***

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 829.7821229050279

# %% [markdown]
# ***R-squared***

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.5700883006312464

# %% [markdown]
# **Result**

# %%
y_pred=lm.predict(X_test)          # LINEAR REGRESSION

# %%
plt.scatter(y_test,y_pred)

# %%
plt.plot(y_test,y_pred)

# %%
y_pred=rfc.predict(X_test)      #RANDOM TREE MODEL

# %%
plt.scatter(y_test,y_pred)

# %%
plt.plot(y_test,y_pred)

# %% [markdown]
# # Linear Regression And Random Tree Model Perform the Best
